# %%
import pandas as pd
import numpy as np
pd.options.display.max_columns=None
pd.options.display.max_colwidth=300
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('/home/bea/Escritorio/KSchool_TFM/Principales/Encuesta_insercion_laboral_titulados_universitarios_2019/EILU_MASTER/CSV/EILU_MAST_2019.csv',
                   sep='\t',)
df.head()
# Out:
#    IDENT  SEXO  EDAD  NACIO NACIO1 NACIO2  PAIS_NACI  TITU  RAMA  AMBITO  \
# 0      1     1     1      1                        1   916     5       9
# 1      2     1     1      1                        1   114     3       1
# 2      3     1     1      1                        2   612     4       6
# 3      4     1     1      1                        1   531     2       5
# 4      5     1     1      1                        1   531     2       5
#
#    T_UNIV  DISCA  PROXY  LUG_RES_PAIS  PAIS_NAC_PADRE  ESTUDIOS_PADRE  \
# 0       3      2      1             1               1               8
# 1       4      2      1             1               1               8
# 2       4      2      1             1               2               7
# 3       1      2      1             1               1               2
# 4       1      2      1             1               1               4
#
#    PAIS_NAC_MADRE  ESTUDIOS_MADRE  EST_B1 EST_B2_1 EST_B2_2 EST_B2_3 EST_B2_4  \
# ...

# %%
df[(df['SEXO']==2)&(df['NACIO']==1)&(df['AMBITO']==1)&(df['TITU']==114)&(df['EDAD']==3)
   &(df['T_UNIV']==1)&(df['TITU']==114)&(df['EST_B11_3']==1)&(df['ESTUDIOS_PADRE']==8)
  &(df['ESTUDIOS_MADRE']==8)&(df['EST2_NC']==9)]
# Out:
#       IDENT  SEXO  EDAD  NACIO NACIO1 NACIO2  PAIS_NACI  TITU  RAMA  AMBITO  \
# 5002   5003     2     3      1                        1   114     3       1
#
#       T_UNIV  DISCA  PROXY  LUG_RES_PAIS  PAIS_NAC_PADRE  ESTUDIOS_PADRE  \
# 5002       1      2      1             1               1               8
#
#       PAIS_NAC_MADRE  ESTUDIOS_MADRE  EST_B1 EST_B2_1 EST_B2_2 EST_B2_3  \
# 5002               1               8       2
#
#      EST_B2_4 EST_B2_5  EST_M1 EST_M2 EST_M3 EST_M4  EST_MES  EST_B8  SAT1  \
# 5002                         2                             2       3     1
#
#      SAT2  EST_B11_1  EST_B11_2  EST_B11_3  EST_B11_4  EST_B11_5  EST_B11_6  \
# 5002    2          1          1          1          2          2          2
#
#      EST_B12 EST_B13_AMB1 EST_B14_1 EST_B15_1 EST_B13_AMB2 EST_B14_2  \
# 5002       1         0311         1         1
#
#      EST_B15_2 EST_B13_AMB3 EST_B14_3 EST_B15_3 EST_B16 EST_B17_M1 EST_B18_1  \
# ...

# %%
df.shape[0]
# Out:
# 11483
